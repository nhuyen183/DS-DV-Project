# %% [markdown]
# <a href="https://colab.research.google.com/github/nhuyen183/DS-DV-Project/blob/master/PROGNOSTICINDEX.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
mydata <- read.csv("./df.csv")
## view the first few rows of the data
head(mydata)
# Out:
#   Gender Age65 BMI GeneralHealth CheckupFreq Exercise Smoked100 SmokerStatus
# 1 0      0     4   2             1           0        0         4
# 2 1      1     2   1             1           1        1         3
# 3 1      1     4   3             1           1        0         4
# 4 1      1     3   2             1           1        1         3
# 5 1      0     4   5             1           1        1         3
# 6 0      1     4   3             1           1        0         4
#   StopSmoking TimeSinceQuitSmk EverUsedEcig EcigLevel HasCTScan
# 1 0           0                0            0         0
# 2 0           7                0            0         0
# 3 0           0                0            0         0
# 4 0           7                1            3         0
# 5 0           7                0            0         0
# 6 0           0                0            0         1
#   HasChronicDisease HasAsthma HadStroke HadHeartDisease HasLungCancer
# 1 0                 0         0         0               0
# 2 0                 0         1         1               0
# 3 0                 0         0         0               0
# 4 0                 0         0         0               0
# 5 0                 0         0         0               0
# 6 0                 0         0         1               0

# %%
summary(mydata)

# %%
xtabs(~HasLungCancer + HasChronicDisease, data = mydata)
# Out:
#              HasChronicDisease
# HasLungCancer      0      1
#             0 960805  87094
#             1    321    355

# %%
mydata$Gender <- factor(mydata$Gender)
mydata$Age65 <- factor(mydata$Age65)
mydata$BMI <- factor(mydata$BMI)
mydata$GeneralHealth <- factor(mydata$GeneralHealth)
mydata$CheckupFreq <- factor(mydata$CheckupFreq)
mydata$Exercise <- factor(mydata$Exercise)
mydata$Smoked100 <- factor(mydata$Smoked100)
mydata$SmokerStatus <- factor(mydata$SmokerStatus)
mydata$StopSmoking <- factor(mydata$StopSmoking)
mydata$TimeSinceQuitSmk <- factor(mydata$TimeSinceQuitSmk)
mydata$EverUsedEcig <- factor(mydata$EverUsedEcig)
mydata$EcigLevel <- factor(mydata$EcigLevel)
mydata$HasCTScan <- factor(mydata$HasCTScan)
mydata$HasChronicDisease <- factor(mydata$HasChronicDisease)
mydata$HasAsthma <- factor(mydata$HasAsthma)
mydata$HadStroke <- factor(mydata$HadStroke)
mydata$HadHeartDisease <- factor(mydata$HadHeartDisease)
mylogit <- glm(HasLungCancer ~ Gender + Age65 + BMI + GeneralHealth + CheckupFreq + Exercise + Smoked100 + SmokerStatus + StopSmoking + TimeSinceQuitSmk + EverUsedEcig + EcigLevel + HasCTScan + HasChronicDisease + HasAsthma + HadStroke + HadHeartDisease, data = mydata, family = "binomial")
# Out:
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”

# %%
summary(mylogit)
# Out:
# Call:
# glm(formula = HasLungCancer ~ Gender + Age65 + BMI + GeneralHealth +
#     CheckupFreq + Exercise + Smoked100 + SmokerStatus + StopSmoking +
#     TimeSinceQuitSmk + EverUsedEcig + EcigLevel + HasCTScan +
#     HasChronicDisease + HasAsthma + HadStroke + HadHeartDisease,
#     family = "binomial", data = mydata)
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -0.7387  -0.0308  -0.0188  -0.0123   4.5795
#
# Coefficients:
#                     Estimate Std. Error z value Pr(>|z|)
# (Intercept)          3.21834  329.69820   0.010 0.992212
# Gender1             -0.21318    0.08104  -2.631 0.008521 **
# Age651               1.02778    0.09492  10.828  < 2e-16 ***
# BMI2                -0.45207    0.17704  -2.553 0.010666 *
# BMI3                -0.74097    0.18084  -4.097 4.18e-05 ***
# BMI4                -0.98076    0.18275  -5.367 8.01e-08 ***
# GeneralHealth2       0.61495    0.24177   2.544 0.010974 *
# GeneralHealth3       1.19600    0.23210   5.153 2.56e-07 ***
# GeneralHealth4       1.46462    0.23836   6.145 8.02e-10 ***
# GeneralHealth5       1.92483    0.24510   7.853 4.05e-15 ***
# CheckupFreq2        -0.52318    0.19494  -2.684 0.007280 **
# CheckupFreq3        -0.39783    0.27317  -1.456 0.145296
# CheckupFreq4        -1.10391    0.38270  -2.885 0.003920 **
# CheckupFreq5       -11.78045  132.88906  -0.089 0.929361
# CheckupFreq8         1.52302    0.71655   2.125 0.033546 *
# Exercise1           -0.27385    0.08305  -3.297 0.000976 ***
# Smoked1001         -11.44680  329.69805  -0.035 0.972304
# SmokerStatus2        0.26585    0.19052   1.395 0.162897
# SmokerStatus3        0.40375    0.59473   0.679 0.497214
# SmokerStatus4      -12.35923  329.69806  -0.037 0.970097
# StopSmoking1        -0.06668    0.17770  -0.375 0.707494
# TimeSinceQuitSmk1   -0.42963    0.73421  -0.585 0.558444
# TimeSinceQuitSmk2   -0.08907    0.71122  -0.125 0.900334
# TimeSinceQuitSmk3   -0.18872    0.71099  -0.265 0.790671
# TimeSinceQuitSmk4    0.24306    0.63626   0.382 0.702455
# TimeSinceQuitSmk5    0.57239    0.59004   0.970 0.331999
# TimeSinceQuitSmk6    0.22097    0.59767   0.370 0.711586
# TimeSinceQuitSmk7   -0.06727    0.58362  -0.115 0.908240
# TimeSinceQuitSmk8  -12.52842  337.30053  -0.037 0.970371
# EverUsedEcig1       -4.39419   11.04554  -0.398 0.690759
# EcigLevel1           4.50771   11.04965   0.408 0.683310
# EcigLevel2           4.50683   11.04897   0.408 0.683350
# EcigLevel3           4.39108   11.04540   0.398 0.690963
# HasCTScan1           2.00109    0.12431  16.097  < 2e-16 ***
# HasCTScan3          -0.87251    0.33663  -2.592 0.009545 **
# HasChronicDisease1   1.41301    0.09226  15.316  < 2e-16 ***
# HasAsthma1          -0.26024    0.10219  -2.547 0.010877 *
# HadStroke1          -0.02460    0.12793  -0.192 0.847498
# HadHeartDisease1    -0.02378    0.10826  -0.220 0.826102
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for binomial family taken to be 1)
#
#     Null deviance: 11284.4  on 1048574  degrees of freedom
# Residual deviance:  9462.5  on 1048536  degrees of freedom
# AIC: 9540.5
#
# Number of Fisher Scoring iterations: 18

# %%
install.packages("aod")
install.packages("ggplot2")

library(aod)
library(ggplot2)
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
wald.test(b = coef(mylogit), Sigma = vcov(mylogit), Terms = 4:6)
# Out:
# Wald test:
# ----------
#
# Chi-squared test:
# X2 = 44.2, df = 3, P(> X2) = 1.4e-09

# %%
## odds ratios and 95% CI
exp(cbind(OR = coef(mylogit), confint(mylogit)))
# Out:
# Waiting for profiling to be done...
#
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: algorithm did not converge”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: algorithm did not converge”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message in regularize.values(x, y, ties, missing(ties), na.rm = na.rm):
# “collapsing to unique 'x' values”
# Warning message in regularize.values(x, y, ties, missing(ties), na.rm = na.rm):
# “collapsing to unique 'x' values”
#                    OR           2.5 %         97.5 %
# (Intercept)        2.498659e+01  1.444129e+93  2.659937e+92
# Gender1            8.080080e-01  6.887808e-01  9.464568e-01
# Age651             2.794861e+00  2.324408e+00  3.372695e+00
# BMI2               6.363120e-01  4.553371e-01  9.131147e-01
# BMI3               4.766509e-01  3.383302e-01  6.886492e-01
# BMI4               3.750265e-01  2.650983e-01  5.436566e-01
# GeneralHealth2     1.849571e+00  1.176305e+00  3.049869e+00
# GeneralHealth3     3.306855e+00  2.150262e+00  5.365744e+00
# GeneralHealth4     4.325894e+00  2.774373e+00  7.095167e+00
# GeneralHealth5     6.853966e+00  4.331766e+00  1.137398e+01
# CheckupFreq2       5.926333e-01  3.952465e-01  8.511467e-01
# CheckupFreq3       6.717734e-01  3.747795e-01  1.102479e+00
# CheckupFreq4       3.315730e-01  1.414487e-01  6.486833e-01
# CheckupFreq5       7.652731e-06  1.959257e-42  9.021649e-43
# CheckupFreq8       4.586069e+00  7.537961e-01  1.454055e+01
# Exercise1          7.604460e-01  6.462456e-01  8.950162e-01
# Smoked1001         1.068364e-05 6.720717e-114 1.672212e-107
# SmokerStatus2      1.304534e+00  8.913990e-01  1.884333e+00
# SmokerStatus3      1.497427e+00  3.640118e-01  4.072217e+00
# SmokerStatus4      4.289987e-06 1.501274e-106 2.272647e-103
# StopSmoking1       9.354962e-01  6.609103e-01  1.328097e+00
# TimeSinceQuitSmk1  6.507529e-01  1.584494e-01  3.192281e+00
# TimeSinceQuitSmk2  9.147786e-01  2.393114e-01  4.362110e+00
# TimeSinceQuitSmk3  8.280154e-01  2.167210e-01  3.947010e+00
# TimeSinceQuitSmk4  1.275141e+00  4.169801e-01  5.534841e+00
# TimeSinceQuitSmk5  1.772499e+00  6.602801e-01  7.246659e+00
# TimeSinceQuitSmk6  1.247291e+00  4.548345e-01  5.150539e+00
# TimeSinceQuitSmk7  9.349456e-01  3.545316e-01  3.790614e+00
# TimeSinceQuitSmk8  3.622243e-06 2.474442e-114 7.692365e-109
# EverUsedEcig1      1.234884e-02  4.807804e-06  4.909238e+00
# EcigLevel1         9.071356e+01  1.525328e-01  2.663925e+05
# EcigLevel2         9.063440e+01  1.580096e-01  2.630532e+05
# EcigLevel3         8.072746e+01  1.934900e-01  2.103470e+05
# HasCTScan1         7.397131e+00  5.758580e+00  9.380195e+00
# HasCTScan3         4.179027e-01  1.997684e-01  7.592619e-01
# HasChronicDisease1 4.108286e+00  3.429197e+00  4.923730e+00
# HasAsthma1         7.708637e-01  6.288495e-01  9.389602e-01
# HadStroke1         9.756982e-01  7.535410e-01  1.245084e+00
# HadHeartDisease1   9.764960e-01  7.866064e-01  1.202858e+00
